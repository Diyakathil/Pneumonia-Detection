# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing
from sklearn import preprocessing
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1-2081502725.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras.datasets import boston_housing
#       4 from sklearn import preprocessing
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#     465     importlib.import_module("tf_keras.src.optimizers")
#     466   else:
# --> 467     importlib.import_module("keras.src.optimizers")
#     468 except (ImportError, AttributeError):
#     469   pass
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.11/dist-packages/keras/__init__.py in <module>
# ...

# %%
#load the dataset
(X_train,Y_train),(X_test,Y_test) = boston_housing.load_data()

# %%
print("Shape of training inputs", X_train.shape)
print("Shape of testing inputs", Y_train.shape)
print("Actual train output", X_test.shape)
print("Actual test output", Y_test.shape)

# %%
X_train[0]

# %%
Y_train[0]

# %%
mean=X_train.mean(axis=0)
std=X_train.std(axis=0)
X_train=(X_train-mean)/std
X_test=(X_test-mean)/std

# %%
X_train = preprocessing.normalize(X_train)
X_test = preprocessing.normalize(X_test)

# %%
X_train[0] #after applying the normalization

# %%
X_train[0].shape

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

# %% [markdown]
# Design Neural Network Architeture

# %%
def HousePredictionModel():
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(X_train[0].shape)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
m= HousePredictionModel()
m.summary()

# %%
num_epochs = 100
all_scores = []

# %%
history = m.fit(x=X_train, y=Y_train, epochs=num_epochs, batch_size=1, verbose=1, validation_data=(X_test, Y_test))

# %%
X_test[1], Y_test[1]

# %%
test_input = X_test[1]

# %%
'''[2.07806276e-04, 0.00000000e+00, 1.68719346e-02, 0.00000000e+00,
        9.21972852e-04, 9.96640855e-03, 1.56583689e-01, 3.96667442e-03,
        1.01130477e-02, 7.28139437e-01, 3.00020416e-02, 6.65691367e-01,
        2.73220840e-02]'''

# %%
#print("Actual Output is :", Y_test[1])
test_input = test_input.reshape(1, -1)
Predicted_value = m.predict(test_input)
print("Difference between actual and predicted output", abs(Predicted_value-Y_test[1]))

# %%
def HousePredictionModel():
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(X_train[0].shape)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
#X_train = preprocessing .normalize()
mean= X_train.mean(axis=0)
X_train = X_train - mean
std = X_train.std(axis=0)
X_train /= std
X_test -= mean
X_test /= std

# %%
history = m.fit(x=X_train, y=Y_train, epochs=num_epochs, batch_size=1, verbose=1, validation_data=(X_test, Y_test))

# %%
X_test[1], Y_test[1]

# %%
test_input = X_test[1]

# %%
#print("Actual Output is :", Y_test[1])
test_input = test_input.reshape(1, -1)
Predicted_value = m.predict(test_input)
print("Difference between actual and predicted output", abs(Predicted_value-Y_test[1]))

# %%
def HousePredictionModel():
    model = Sequential()
    #model.add(Dense(128, activation='relu', input_shape=(X_train[0].shape)))
    model.add(Dense(64, activation='relu', input_shape=(X_train[0].shape)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='sgd', loss='mse', metrics=['mae'])
    return model

# %%
m= HousePredictionModel()
m.summary()

# %%
num_epochs = 100
all_scores = []

# %%
history = m.fit(x=X_train, y=Y_train, epochs=num_epochs, batch_size=1, verbose=1, validation_data=(X_test, Y_test))

# %%
X_test[1], Y_test[1]

# %%
test_input = X_test[1]

# %%
#print("Actual Output is :", Y_test[1])
test_input = test_input.reshape(1, -1)
Predicted_value = m.predict(test_input)
print("Difference between actual and predicted output", abs(Predicted_value-Y_test[1]))

# %%
#having 8 neuron is based on the number of available features
model = Sequential()
model.add(Dense(10,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(9,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam',loss='mse', metrics=['accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
